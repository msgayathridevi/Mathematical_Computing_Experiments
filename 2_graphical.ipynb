# %%
# !pip install pulp
# !pip install passlib==1.7.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 52.7 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.8/507.8 kB 17.1 MB/s eta 0:00:00
# ...

# %%
from pulp import *
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create an object of a model
prob = LpProblem("Simple LP Problem", LpMinimize)

# Define the decision variables
x1 = LpVariable("x1", 0)
x2 = LpVariable("x2", 0)

# Define the objective function
prob += 60*x1 + 40*x2

# Define the constraints
prob += 4*x1 + 4*x2 >= 10.0, "1st constraint"
prob += 2*x1 + x2 >= 4.0, "2nd constraint"
prob += 6*x1 + 2*x2 <= 12.0, "3rd constraint"

# Solve the linear programming problem
prob.solve()

# Print the results
print ("Status: ", LpStatus[prob.status])

for v in prob.variables():
    print (v.name, "=", v.varValue)

print ("The optimal value of the objective function is = ", value(prob.objective))
# Out:
# Status:  Optimal
# x1 = 1.5
# x2 = 1.0
# The optimal value of the objective function is =  130.0
# /usr/local/lib/python3.9/dist-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
# Plot the optimal solution
# manual def of coeff
x = np.arange(0, 4)
plt.plot(x, 2.5 - x, label = '4x1 + 4x2 >= 10')
plt.plot(x, 4 - 2 * x, label= ' 2x1 + x2 >= 4')
plt.plot(x, 6 - 3 * x, label = '6x1 + 2x2 <= 12')

plt.axis([0, 3, 0, 6])
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot the optimal solution
x = np.arange(0, 4)
# plot after conversion
plt.plot(x, 2.5 - x, label = '4x1 + 4x2 >= 10')
plt.plot(x, 4 - 2 * x, label= ' 2x1 + x2 >= 4')
plt.plot(x, 6 - 3 * x, label = '6x1 + 2x2 <= 12')
# plt.plot(x, 2 - 2/3*x, '--')

# Define the boundaries of the feasible area in the plot
# manual feasible area def
x = [0, 1.5, 1.75, 0]
y = [4, 1, 0.75, 6]
plt.fill(x, y, 'yellow')

plt.text(0.1, 4, 'Feasible \n Region', size = '11')
plt.annotate('Optimal \n solution\n(1.5, 1)', xy = (1.5, 1.0))

plt.xlabel("x1")
plt.ylabel("x2")
plt.axis([0, 3, 0, 6])
plt.grid(True)
plt.legend()
plt.show()

# %%
# prob 2

# Create an object of a model
prob = LpProblem("Simple LP Problem", LpMinimize)

# Define the decision variables
x1 = LpVariable("x1", 0)
x2 = LpVariable("x2", 0)

# Define the objective function
prob += 5*x1 + 4*x2

# Define the constraints
prob += 4*x1 + x2 >= 40.0, "1st constraint"
prob += 2*x1 + 3*x2 >= 90.0, "2nd constraint"

# Solve the linear programming problem
prob.solve()

# Print the results
print ("Status: ", LpStatus[prob.status])

for v in prob.variables():
    print (v.name, "=", v.varValue)

print ("The optimal value of the objective function is = ", value(prob.objective))
# Out:
# Status:  Optimal
# x1 = 3.0
# x2 = 28.0
# The optimal value of the objective function is =  127.0

# %%
# Plot the optimal solution
x = np.arange(0, 60)
# plot after conversion
plt.plot(x, 40 - 4*x, label = '4*x1 + x2 >= 40.0')
plt.plot(x, 30 - (2/3) * x, label= ' 2*x1 + 3*x2 >= 90.0')

plt.axis([0, 55, 0, 46])
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot the optimal solution
x = np.arange(0, 60)
# plot after conversion
plt.plot(x, 40 - 4*x, label = '4*x1 + x2 >= 40.0')
plt.plot(x, 30 - (2/3) * x, label= ' 2*x1 + 3*x2 >= 90.0')
# plt.plot(x, 2 - 2/3*x, '--')

# Define the boundaries of the feasible area in the plot
# manual feasible area def
x = [0, 3, 45,45]
y = [40, 28, 0,40]
plt.fill(x, y, 'yellow')

plt.text(20,35, 'Feasible \n Region', size = '11')
plt.annotate('Optimal \n solution\n(3,28)', xy = (3.0,28.0))

# plt.xlabel("x1")
# plt.ylabel("x2")
plt.axis([0, 45, 0, 40])
plt.grid(True)
plt.legend()
plt.show()

# %%
# prob 3 max

# Create an object of a model
prob = LpProblem("Simple LP Problem", LpMaximize)

# Define the decision variables
x1 = LpVariable("x1", 0)
x2 = LpVariable("x2", 0)

# Define the objective function
prob += 2*x1 + 3*x2

# Define the constraints
prob += x1 + x2 <= 30.0, "1st constraint"
prob += x2 <= 12.0, "2nd constraint"
prob += x1 <= 20.0, "3rd constraint"

# Solve the linear programming problem
prob.solve()

# Print the results
print ("Status: ", LpStatus[prob.status])

for v in prob.variables():
    print (v.name, "=", v.varValue)

print ("The optimal value of the objective function is = ", value(prob.objective))
# Out:
# Status:  Optimal
# x1 = 18.0
# x2 = 12.0
# The optimal value of the objective function is =  72.0
# /usr/local/lib/python3.9/dist-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
# Plot the optimal solution
x = np.arange(0, 60)
# plot after conversion
plt.plot(x, 30-x, label = 'x1 + x2 <= 30.0')
plt.plot(x, 12-0*x, label= ' x2 <= 12.0')
x=[20,20]
y=[49,0]
plt.plot(x,y,label= 'x1 <= 20.0')

plt.axis([0, 55, 0, 46])
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot the optimal solution
x = np.arange(0, 60)
# plot after conversion
plt.plot(x, 30-x, label = 'x1 + x2 <= 30.0')
plt.plot(x, 12-0*x, label= ' x2 <= 12.0')
x=[20,20]
y=[49,0]
plt.plot(x,y,label= 'x1 <= 20.0')

# Define the boundaries of the feasible area in the plot
# manual feasible area def
x = [0,0,18,20,20]
y = [0,12,12,10,0]
plt.fill(x, y, 'yellow')

plt.text(5,5, 'Feasible \n Region', size = '11')
plt.annotate('Optimal \n solution\n(18,12)', xy = (18,12))

# plt.xlabel("x1")
# plt.ylabel("x2")
plt.axis([0, 45, 0, 40])
plt.grid(True)
plt.legend()
plt.show()
